# %%
import matplotlib.pyplot as plot
import numpy as np
import os
# %matplotlib inline

# %%
folder_name = "./Dataset/TrainData/"
file_names = os.listdir(folder_name)
file_names = [folder_name + file_name for file_name in file_names]
images = [plot.imread(file_name) for file_name in file_names]
images = np.array(images)

# %%
n = images.shape[0]
print("Shape:", images.shape)
# Out:
# Shape: (2952, 256, 256, 3)

# %% [markdown]
# # Extract Features

# %%
gray_images = np.mean(images, axis=3)

# %%
means = np.mean(gray_images, axis=(1, 2))
assert means.shape == (n,)

# %%
medians = np.median(gray_images, axis=(1, 2))
assert medians.shape == (n,)

# %%
maxes = np.max(gray_images, axis=(1, 2))
mins = np.min(gray_images, axis=(1, 2))
mid_ranges = (maxes + mins) / 2
assert mid_ranges.shape == (n,)

# %%
flat_gray_images = np.reshape(gray_images, (n, -1))
assert flat_gray_images.shape == (n, 256 * 256)

# %%
sorted_images = np.sort(flat_gray_images, axis=1)

# %%
quartile_size = int((256 * 256) / 4)
q_ones = sorted_images[:, quartile_size]
q_threes = sorted_images[:, quartile_size * 3]
IQRs = q_threes - q_ones
assert IQRs.shape == (n,)

# %%
std_devs = np.std(gray_images, axis=(1, 2))
assert std_devs.shape == (n,)

# %% [markdown]
# ## Showdown

# %%
from pandas import DataFrame

# %%
data = np.array([means, medians, mid_ranges, IQRs, std_devs, file_names]).T
columns = ["Mean", "Median", "Mid Range", "IQR", "Std Dev", "File Name"]
df = DataFrame(data, columns=columns)

# %%
df['Mean'] = df['Mean'].astype(np.float64)
df['Median'] = df['Median'].astype(np.float64)
df['Mid Range'] = df['Mid Range'].astype(np.float64)
df['IQR'] = df['IQR'].astype(np.float64)
df['Std Dev'] = df['Std Dev'].astype(np.float64)
df['File Name'] = df['File Name'].astype(np.str)

# %%
df.to_csv("./Dataset/train.csv")

# %%
car = plot.imread("./Dataset/TestData/car14-045-270.png")

# %%
plot.imshow(car)

# %%
feature = [
    np.mean(car),
    np.median(car),
    (np.max(car) + np.min(car)) / 2,
]
flat_car = car.reshape((-1))
sorted_car = np.sort(flat_car)
q1 = sorted_car[quartile_size]
q3 = sorted_car[quartile_size * 3]
feature.append(q3 - q1)
feature.append(np.std(car))

# %%
feature

# %%
def euclidean_dist(df: DataFrame):
    cols = ['Mean', 'Median', 'Mid Range', 'IQR', 'Std Dev']
    df = df[cols]
    for i, col in enumerate(cols):
        df[col] = (df[col] - feature[i]) ** 2
    diff_col = df.sum(axis=1)
    return diff_col

# %%
new_df = (df.copy()
          .assign(sort_col=euclidean_dist)
          .sort_values('sort_col'))
# Out:
# (2952, 5) (2952,)
# D:\Software\Study\Anaconda3\envs\data-mining\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-b3102c980570> in <module>()
#       1 new_df = (df.copy()
#       2           .assign(sort_col=euclidean_dist)
# ----> 3           .sort_values('Sorter'))
#
# D:\Software\Study\Anaconda3\envs\data-mining\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4419             by = by[0]
#    4420             k = self._get_label_or_level_values(by, axis=axis,
# -> 4421                                                 stacklevel=stacklevel)
#    4422
#    4423             if isinstance(ascending, (tuple, list)):
#
# D:\Software\Study\Anaconda3\envs\data-mining\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
#    1384         # Check for duplicates
#
# KeyError: 'Sorter'

# %%
new_df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Mean</th>
#       <th>Median</th>
#       <th>Mid Range</th>
#       <th>IQR</th>
#       <th>Std Dev</th>
#       <th>File Name</th>
#       <th>sort_col</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.465942</td>
#       <td>0.437908</td>
#       <td>0.533987</td>
#       <td>0.279739</td>
#       <td>0.176985</td>
#       <td>./Dataset/TrainData/apple1-000-000.png</td>
#       <td>0.034554</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.431798</td>
#       <td>0.347712</td>
#       <td>0.564052</td>
#       <td>0.295425</td>
#       <td>0.189585</td>
#       <td>./Dataset/TrainData/apple1-022-000.png</td>
#       <td>0.061270</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.451734</td>
#       <td>0.377778</td>
#       <td>0.535294</td>
#       <td>0.281046</td>
#       <td>0.169429</td>
#       <td>./Dataset/TrainData/apple1-022-090.png</td>
#       <td>0.044899</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.450856</td>
#       <td>0.396078</td>
#       <td>0.584314</td>
#       <td>0.223529</td>
#       <td>0.146109</td>
#       <td>./Dataset/TrainData/apple1-022-180.png</td>
#       <td>0.032475</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.439488</td>
#       <td>0.394771</td>
#       <td>0.538562</td>
#       <td>0.196078</td>
#       <td>0.129402</td>
#       <td>./Dataset/TrainData/apple1-022-270.png</td>
#       <td>0.026366</td>
#     </tr>
#   </tbody>
# </table>
# </div>
